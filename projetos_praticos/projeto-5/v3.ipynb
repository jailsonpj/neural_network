# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,scale,minmax_scale
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2,mutual_info_classif
from pandas.tools.plotting import scatter_matrix

# %%
data = pd.read_csv('all/train.csv',delimiter=',')

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.head()
# Out:
#     id  Age      BMI  Glucose  Insulin    HOMA   Leptin  Adiponectin  \
# 0  114   47  22.0300       84    2.869  0.5900  26.6500      38.0400
# 1  104   75  30.4800      152    7.010  2.6283  50.5300      10.0600
# 2   90   25  22.8600       82    4.090  0.8273  20.4500      23.6700
# 3    8   54  24.2188       86    3.730  0.7913   8.6874       3.7052
# 4    9   69  35.0927      101    5.646  1.4066  83.4821       6.7970
#
#    Resistin    MCP.1  Classification
# 0    3.3200  191.720               1
# 1   11.7300   99.450               2
# 2    5.1400  313.730               1
# 3   10.3446  635.049               2
# 4   82.1000  263.499               1

# %%
contagem = data.groupby('Classification').size()
print(contagem)
# Out:
# Classification
# 1    43
# 2    49
# dtype: int64

# %%
y = data['Classification']
X = data.drop('Classification',axis=1)
X = X.drop('id',axis=1)

# %%
X.head(10)
# Out:
#    Age      BMI  Glucose  Insulin    HOMA   Leptin  Adiponectin  Resistin  \
# 0   47  22.0300       84    2.869  0.5900  26.6500      38.0400    3.3200
# 1   75  30.4800      152    7.010  2.6283  50.5300      10.0600   11.7300
# 2   25  22.8600       82    4.090  0.8273  20.4500      23.6700    5.1400
# 3   54  24.2188       86    3.730  0.7913   8.6874       3.7052   10.3446
# 4   69  35.0927      101    5.646  1.4066  83.4821       6.7970   82.1000
# 5   44  20.7600       86    7.553  1.6000  14.0900      20.3200    7.6400
# 6   41  26.6728       97   22.033  5.2718  44.7059      13.4949   27.8325
# 7   45  29.3848       90    4.713  1.0463  23.8479       6.6442   15.5562
# 8   46  33.1800       92    5.750  1.3049  18.6900       9.1600    8.8900
# 9   66  27.7000       90    6.042  1.3413  24.8460       7.6521    6.7052
#
#      MCP.1
# 0  191.720
# 1   99.450
# 2  313.730
# 3  635.049
# 4  263.499
# 5   63.610
# 6  783.796
# 7  621.273
# 8  209.190
# 9  225.880

# %%
cor = X.corr(method='pearson')
cor
# Out:
#                   Age       BMI   Glucose   Insulin      HOMA    Leptin  \
# Age          1.000000  0.046243  0.255007 -0.014352  0.070058  0.057603
# BMI          0.046243  1.000000  0.120155  0.110721  0.090896  0.641596
# Glucose      0.255007  0.120155  1.000000  0.472247  0.648375  0.320182
# Insulin     -0.014352  0.110721  0.472247  1.000000  0.939592  0.244273
# HOMA         0.070058  0.090896  0.648375  0.939592  1.000000  0.284644
# Leptin       0.057603  0.641596  0.320182  0.244273  0.284644  1.000000
# Adiponectin -0.195921 -0.326366 -0.108719 -0.002093 -0.021025 -0.134664
# Resistin     0.084157  0.226390  0.236396  0.150592  0.237270  0.384415
# MCP.1       -0.031636  0.227154 -0.007520  0.080775  0.107946  0.058682
#
#              Adiponectin  Resistin     MCP.1
# Age            -0.195921  0.084157 -0.031636
# BMI            -0.326366  0.226390  0.227154
# Glucose        -0.108719  0.236396 -0.007520
# Insulin        -0.002093  0.150592  0.080775
# HOMA           -0.021025  0.237270  0.107946
# Leptin         -0.134664  0.384415  0.058682
# Adiponectin     1.000000 -0.250135 -0.154118
# Resistin       -0.250135  1.000000  0.285751
# MCP.1          -0.154118  0.285751  1.000000

# %%
X_new = SelectKBest(mutual_info_classif, k=6).fit_transform(X, y)

# %%
X_new
# Out:
# array([[4.700000e+01, 8.400000e+01, 5.900000e-01, 3.804000e+01,
#         3.320000e+00, 1.917200e+02],
#        [7.500000e+01, 1.520000e+02, 2.628300e+00, 1.006000e+01,
#         1.173000e+01, 9.945000e+01],
#        [2.500000e+01, 8.200000e+01, 8.273000e-01, 2.367000e+01,
#         5.140000e+00, 3.137300e+02],
#        [5.400000e+01, 8.600000e+01, 7.913000e-01, 3.705200e+00,
#         1.034460e+01, 6.350490e+02],
#        [6.900000e+01, 1.010000e+02, 1.406600e+00, 6.797000e+00,
#         8.210000e+01, 2.634990e+02],
#        [4.400000e+01, 8.600000e+01, 1.600000e+00, 2.032000e+01,
#         7.640000e+00, 6.361000e+01],
#        [4.100000e+01, 9.700000e+01, 5.271800e+00, 1.349490e+01,
#         2.783250e+01, 7.837960e+02],
#        [4.500000e+01, 9.000000e+01, 1.046300e+00, 6.644200e+00,
#         1.555620e+01, 6.212730e+02],
#        [4.600000e+01, 9.200000e+01, 1.304900e+00, 9.160000e+00,
#         8.890000e+00, 2.091900e+02],
#        [6.600000e+01, 9.000000e+01, 1.341300e+00, 7.652100e+00,
#         6.705200e+00, 2.258800e+02],
#        [6.900000e+01, 9.300000e+01, 1.245600e+00, 1.178800e+01,
#         1.178800e+01, 2.701420e+02],
#        [5.900000e+01, 7.700000e+01, 6.055000e-01, 1.644050e+01,
#         3.169040e+01, 9.104890e+02],
#        [3.600000e+01, 8.000000e+01, 1.300400e+00, 5.065900e+00,
#         1.572190e+01, 5.813130e+02],
#        [6.400000e+01, 9.800000e+01, 1.377900e+00, 4.784000e+00,
#         1.391240e+01, 3.959760e+02],
#        [4.900000e+01, 7.800000e+01, 5.079000e-01, 3.886100e+00,
#         2.294250e+01, 7.376720e+02],
#        [7.100000e+01, 1.120000e+02, 2.871800e+00, 5.486100e+00,
#         4.274470e+01, 7.998980e+02],
#        [3.800000e+01, 9.500000e+01, 1.232800e+00, 4.771900e+00,
#         1.573610e+01, 1.990550e+02],
#        [7.200000e+01, 8.300000e+01, 2.241600e+00, 2.784900e+00,
#         1.476970e+01, 2.320180e+02],
#        [7.400000e+01, 8.800000e+01, 6.538000e-01, 7.652200e+00,
#         1.835570e+01, 5.724010e+02],
#        [4.400000e+01, 1.140000e+02, 4.468300e+00, 2.037000e+01,
#         4.620000e+00, 2.206600e+02],
#        [6.600000e+01, 9.000000e+01, 2.052400e+00, 1.035530e+01,
#         2.338190e+01, 1.102110e+03],
#        [7.700000e+01, 8.500000e+01, 9.603000e-01, 9.753300e+00,
#         1.177400e+01, 4.888290e+02],
#        [5.200000e+01, 8.700000e+01, 6.483500e+00, 6.268500e+00,
#         2.424590e+01, 7.646670e+02],
#        [6.900000e+01, 8.900000e+01, 2.349900e+00, 8.286300e+00,
#         4.530000e+00, 2.157690e+02],
#        [4.500000e+01, 9.200000e+01, 7.557000e-01, 1.210000e+01,
#         1.096000e+01, 2.682300e+02],
#        [7.600000e+01, 9.400000e+01, 3.262400e+00, 9.346600e+00,
#         8.415600e+00, 3.772270e+02],
#        [3.800000e+01, 7.500000e+01, 1.069700e+00, 1.795000e+01,
#         9.350000e+00, 1.650200e+02],
#        [4.000000e+01, 1.030000e+02, 6.179000e-01, 6.783900e+00,
#         2.601360e+01, 2.931230e+02],
#        [4.500000e+01, 1.020000e+02, 3.485200e+00, 2.105660e+01,
#         2.303410e+01, 5.524440e+02],
#        [4.800000e+01, 7.000000e+01, 4.674000e-01, 9.702400e+00,
#         7.995800e+00, 4.171140e+02],
#        [7.600000e+01, 1.100000e+02, 7.111900e+00, 4.935600e+00,
#         8.494000e+00, 4.584300e+01],
#        [5.400000e+01, 1.190000e+02, 3.496000e+00, 8.010000e+00,
#         5.060000e+00, 2.182800e+02],
#        [4.500000e+01, 9.200000e+01, 7.807000e-01, 1.667000e+01,
#         7.840000e+00, 1.938700e+02],
#        [5.100000e+01, 7.700000e+01, 7.322000e-01, 3.192100e+00,
#         1.037520e+01, 4.738590e+02],
#        [7.700000e+01, 7.600000e+01, 7.276000e-01, 8.125600e+00,
#         1.726150e+01, 6.182720e+02],
#        [6.900000e+01, 1.080000e+02, 2.346500e+00, 5.288000e+00,
#         1.648510e+01, 3.535680e+02],
#        [5.500000e+01, 9.200000e+01, 3.775000e+00, 1.101850e+01,
#         7.165100e+00, 4.833770e+02],
#        [8.600000e+01, 9.200000e+01, 8.054000e-01, 4.819200e+00,
#         1.057640e+01, 7.739200e+02],
#        [4.300000e+01, 1.010000e+02, 2.629600e+00, 6.420300e+00,
#         1.610000e+01, 8.067240e+02],
#        [4.200000e+01, 9.800000e+01, 1.008500e+00, 6.695600e+00,
#         5.367170e+01, 1.041843e+03],
#        [8.300000e+01, 9.200000e+01, 7.069000e-01, 5.429300e+00,
#         4.064000e+00, 4.687860e+02],
#        [4.500000e+01, 8.300000e+01, 1.384000e+00, 4.617100e+00,
#         8.704500e+00, 5.861730e+02],
#        [8.500000e+01, 1.960000e+02, 2.505030e+01, 7.901700e+00,
#         5.521530e+01, 1.078359e+03],
#        [4.300000e+01, 8.900000e+01, 5.091900e+00, 8.301000e+00,
#         6.710300e+00, 9.602460e+02],
#        [2.400000e+01, 8.800000e+01, 1.330000e+00, 3.606000e+01,
#         6.850000e+00, 6.322200e+02],
#        [2.900000e+01, 8.400000e+01, 1.203800e+00, 6.209600e+00,
#         2.460330e+01, 9.049810e+02],
#        [6.500000e+01, 9.700000e+01, 1.371000e+00, 2.254000e+01,
#         1.033000e+01, 3.140500e+02],
#        [3.600000e+01, 8.600000e+01, 9.217000e-01, 8.600000e+00,
#         9.153900e+00, 5.342240e+02],
#        [4.900000e+01, 9.200000e+01, 7.321000e-01, 1.367980e+01,
#         1.031760e+01, 5.304100e+02],
#        [7.800000e+01, 6.000000e+01, 5.192000e-01, 1.056730e+01,
#         4.663800e+00, 2.097490e+02],
#        [8.100000e+01, 1.000000e+02, 2.385000e+00, 1.063650e+01,
#         2.955830e+01, 4.261750e+02],
#        [7.100000e+01, 1.020000e+02, 2.098300e+00, 8.130000e+00,
#         4.298900e+00, 2.009760e+02],
#        [4.200000e+01, 9.300000e+01, 6.880000e-01, 8.462900e+00,
#         1.737620e+01, 3.219190e+02],
#        [4.400000e+01, 1.060000e+02, 1.528530e+01, 1.610000e+01,
#         5.310000e+00, 2.447500e+02],
#        [5.000000e+01, 1.060000e+02, 1.752600e+00, 4.667600e+00,
#         1.178390e+01, 8.871600e+02],
#        [4.800000e+01, 9.900000e+01, 7.002900e+00, 2.157000e+01,
#         1.015730e+01, 7.380340e+02],
#        [6.000000e+01, 1.030000e+02, 1.305400e+00, 2.194300e+00,
#         2.025350e+01, 3.789960e+02],
#        [3.500000e+01, 8.400000e+01, 9.067000e-01, 9.048200e+00,
#         1.643710e+01, 7.337970e+02],
#        [7.200000e+01, 8.200000e+01, 5.704000e-01, 3.375000e+01,
#         3.270000e+00, 3.924600e+02],
#        [6.600000e+01, 8.900000e+01, 1.432200e+00, 8.430000e+00,
#         1.491920e+01, 2.694870e+02],
#        [8.200000e+01, 1.000000e+02, 4.459000e+00, 9.923600e+00,
#         1.994690e+01, 9.943160e+02],
#        [3.400000e+01, 8.700000e+01, 9.721000e-01, 7.642800e+00,
#         5.625900e+00, 5.727830e+02],
#        [5.400000e+01, 9.000000e+01, 1.229200e+00, 9.731400e+00,
#         1.019300e+01, 1.227910e+03],
#        [6.000000e+01, 1.310000e+02, 9.736000e+00, 8.404400e+00,
#         1.150000e+01, 3.960210e+02],
#        [8.200000e+01, 9.100000e+01, 1.009700e+00, 2.243200e+01,
#         9.277200e+00, 5.546970e+02],
#        [6.800000e+01, 1.310000e+02, 2.633500e+00, 1.190000e+01,
#         4.190000e+00, 1.984000e+02],
#        [3.200000e+01, 8.700000e+01, 3.010000e+00, 5.100000e+00,
#         1.710220e+01, 5.884600e+02],
#        [5.900000e+01, 9.800000e+01, 1.658800e+00, 4.230100e+00,
#         8.204900e+00, 3.553100e+02],
#        [5.100000e+01, 1.050000e+02, 1.561800e+00, 1.276000e+01,
#         3.210000e+00, 5.136600e+02],
#        [6.900000e+01, 1.120000e+02, 1.846300e+00, 4.138000e+00,
#         1.569880e+01, 7.132390e+02],
#        [6.700000e+01, 7.900000e+01, 1.133900e+00, 2.194300e+00,
#         4.207500e+00, 5.853070e+02],
#        [6.800000e+01, 7.700000e+01, 6.127000e-01, 7.169600e+00,
#         1.276600e+01, 9.282200e+02],
#        [3.400000e+01, 9.200000e+01, 4.924200e+00, 2.182370e+01,
#         1.206530e+01, 4.819490e+02],
#        [7.300000e+01, 1.340000e+02, 1.862900e+00, 3.335700e+00,
#         6.892400e+00, 7.889020e+02],
#        [7.600000e+01, 8.300000e+01, 1.100600e+00, 7.370000e+00,
#         8.043800e+00, 6.987890e+02],
#        [4.800000e+01, 9.000000e+01, 5.639000e-01, 1.022230e+01,
#         1.611030e+01, 1.698440e+03],
#        [7.500000e+01, 8.500000e+01, 1.089600e+00, 9.000800e+00,
#         7.576700e+00, 3.353930e+02],
#        [2.800000e+01, 8.700000e+01, 1.840400e+00, 4.794200e+00,
#         2.144370e+01, 3.586240e+02],
#        [4.500000e+01, 1.160000e+02, 1.402600e+00, 4.294700e+00,
#         5.263300e+00, 5.185860e+02],
#        [6.500000e+01, 9.700000e+01, 2.510100e+00, 3.710100e+00,
#         2.046850e+01, 3.966480e+02],
#        [7.600000e+01, 1.180000e+02, 1.883200e+00, 1.325130e+01,
#         5.104200e+00, 2.806940e+02],
#        [3.500000e+01, 9.000000e+01, 1.513400e+00, 6.966900e+00,
#         2.203700e+01, 6.679280e+02],
#        [5.100000e+01, 9.300000e+01, 1.001100e+00, 5.807600e+00,
#         5.570600e+00, 9.060000e+01],
#        [7.100000e+01, 1.040000e+02, 4.668900e+00, 1.656000e+00,
#         4.924180e+01, 2.560010e+02],
#        [8.500000e+01, 9.600000e+01, 1.056600e+00, 7.931700e+00,
#         9.613500e+00, 2.320060e+02],
#        [6.200000e+01, 1.000000e+02, 1.117400e+00, 2.142000e+01,
#         7.320000e+00, 3.301600e+02],
#        [4.000000e+01, 1.280000e+02, 1.322730e+01, 6.161000e+00,
#         1.755500e+01, 6.382610e+02],
#        [3.400000e+01, 7.800000e+01, 6.674000e-01, 1.311000e+01,
#         6.920000e+00, 3.546000e+02],
#        [6.500000e+01, 8.500000e+01, 3.071400e+00, 7.282900e+00,
#         1.946320e+01, 1.698440e+03],
#        [4.900000e+01, 7.000000e+01, 1.449700e+00, 1.073170e+01,
#         2.076800e+01, 6.024860e+02],
#        [4.600000e+01, 8.600000e+01, 7.836200e+00, 9.760000e+00,
#         5.680000e+00, 3.120000e+02],
#        [6.600000e+01, 1.010000e+02, 3.869800e+00, 7.539600e+00,
#         2.232020e+01, 8.649680e+02]])

# %%
#dados_amp.head(10)
#X = X.drop(['Age','HOMA','Glucose'],axis=1)


#clf = Pipeline([
#  ('feature_selection', SelectFromModel(LinearSVC(penalty="l1"))),
#  ('classification', RandomForestClassifier())
#])
#clf.fit(X, y)

# %%
#cols1 = list(X.columns)
#pca = PCA(n_components=5,whiten=True)
#dados_pca = pca.fit_transform(X[cols1].values)
#dados_pca = pd.DataFrame(dados_pca,columns=['comp1','comp2','comp3','comp4','comp5'])

# %%
#X.head()

# %%
param = {'hidden_layer_sizes':[(3,3),(2,4),(4,2),(6,),(2,3),(8,),(4,4),(2,6),(6,2),(7,1),(1,7),(6,4),(5,3),(5,2)],'activation':['relu','tanh','logistic'],'learning_rate_init':[0.01,0.1,0.001]}

# %%
model = MLPClassifier(solver='lbfgs')

# %%
clf = GridSearchCV(model,param,cv=5)

# %%
clf.fit(X_new,y)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='lbfgs', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'hidden_layer_sizes': [(3, 3), (2, 4), (4, 2), (6,), (2, 3), (8,), (4, 4), (2, 6), (6, 2), (7, 1), (1, 7), (6, 4), (5, 3), (5, 2)], 'activation': ['relu', 'tanh', 'logistic'], 'learning_rate_init': [0.01, 0.1, 0.001]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
clf.best_score_
# Out:
# 0.6630434782608695

# %% [markdown]
# # Teste

# %%
data_test = pd.read_csv('all/test.csv',delimiter=',')

# %%
id_test = data_test['id']
data_test = data_test.drop('id',axis=1)

# %%
#cols1 = list(data_test.columns)
#pca = PCA(n_components=5,whiten=True)
#dados_pca = pca.fit_transform(data_test[cols1].values)
#dados_pca = pd.DataFrame(dados_pca,columns=['comp1','comp2','comp3','comp4','comp5'])
#data_test = data_test.drop(['Age','Adiponectin','MCP.1','BMI'],axis=1)

# %%
#data_test = data_test.drop(['Age','HOMA','Glucose'],axis=1)

# %%
pred = clf.predict(data_test)

# %%
pred

# %%
data_out = {
    'id':id_test,
    'Classification':pred
}

# %%
classi_out = pd.DataFrame(data_out,columns=['id','Classification'])

# %%
classi_out

# %%
#classi_out.to_csv('submission.csv',index=False)
